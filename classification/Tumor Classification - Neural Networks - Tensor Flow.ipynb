# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DATA/cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(), cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,8))
df.corr()['benign_0__mal_1'][:-1].sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
X = df.drop('benign_0__mal_1', axis=1).values

# %%
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train) # Keep in mind only want to fit to our training data

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model= Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

# Binary Classification - So use sigmoid for activation function
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test, y_test)) # High number of epochs to show overfitting example
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6882 - val_loss: 0.6773
# Epoch 2/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6696 - val_loss: 0.6610
# Epoch 3/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6536 - val_loss: 0.6452
# Epoch 4/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6362 - val_loss: 0.6261
# Epoch 5/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6140 - val_loss: 0.5991
# Epoch 6/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5798 - val_loss: 0.5550
# Epoch 7/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5335 - val_loss: 0.5030
# Epoch 8/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4832 - val_loss: 0.4557
# Epoch 9/600
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4323 - val_loss: 0.4059
# Epoch 10/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
# Tells us we are overfitting to our dataset, too many epochs.

# %%
model= Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

# Binary Classification - So use sigmoid for activation function
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# help(EarlyStopping)

# %%
early_stop = EarlyStopping(monitor='val_loss',mode = 'min', patience=25)

# %%
model.fit(x=X_train, y=y_train, epochs=1000, validation_data=(X_test, y_test),
         callbacks=[early_stop])   # Demonstratings early stop
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6751 - val_loss: 0.6532
# Epoch 2/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6365 - val_loss: 0.6212
# Epoch 3/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6024 - val_loss: 0.5853
# Epoch 4/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5655 - val_loss: 0.5468
# Epoch 5/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5227 - val_loss: 0.4999
# Epoch 6/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4766 - val_loss: 0.4508
# Epoch 7/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4315 - val_loss: 0.4080
# Epoch 8/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3906 - val_loss: 0.3690
# Epoch 9/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3551 - val_loss: 0.3327
# Epoch 10/1000
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
# Can also add in drop out layers to prevent over fitting

# %%
from tensorflow.keras.layers import Dropout

# %%
model= Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dropout(0.5))       # Percentage of Neurons randomly turning off - between 0.2 and 0.5 is norm
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.5)) 

# Binary Classification - So use sigmoid for activation function
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=1000, validation_data=(X_test, y_test),
         callbacks=[early_stop])   # Demonstratings early stop
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7126 - val_loss: 0.6899
# Epoch 2/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7032 - val_loss: 0.6720
# Epoch 3/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6840 - val_loss: 0.6619
# Epoch 4/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6593 - val_loss: 0.6466
# Epoch 5/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6456 - val_loss: 0.6273
# Epoch 6/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6503 - val_loss: 0.6096
# Epoch 7/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6339 - val_loss: 0.5911
# Epoch 8/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6183 - val_loss: 0.5729
# Epoch 9/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5927 - val_loss: 0.5458
# Epoch 10/1000
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
predictions = model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        55
#            1       0.99      0.97      0.98        88
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[54  1]
#  [ 3 85]]
